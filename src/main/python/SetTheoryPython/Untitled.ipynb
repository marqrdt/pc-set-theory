# %%
import re

tto_re = re.compile(r'(r|R)*T\[(\w+)\]M\[(\w+)\]')
tto_strings = ['RT[0]M[5]', 'T[3]M[11]']

# %%
import abjad
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import abjad
#
# ModuleNotFoundError: No module named 'abjad'

# %%
import itertools

# %%
row = [11, 1, 2, 10, 8, 5, 3, 9, 4, 7, 6]

# %%
[x % 12 for x in itertools.accumulate(row) ]
# Out:
# [11, 0, 2, 0, 8, 1, 4, 1, 5, 0, 6]

# %%
my_score = abjad.Score()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 my_score = abjad.Score()
#
# NameError: name 'abjad' is not defined

# %%
pip install abjad
# Out:
# ...
#   Using cached abjad-3.13.tar.gz (419 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [17 lines of output]
#
# ...
#       Unsupported Python version
# ...
#
#       This version of Abjad requires Python 3.10, but you're trying to
#       install it on Python 3.9.
#
#       This may be because you are using a version of pip that doesn't
#       understand the python_requires classifier. Make sure you
#       have pip >= 9.0 and setuptools >= 24.2, then try again:
#
#           $ python -m pip install --upgrade pip setuptools
#           $ python -m pip install abjad
#
#       This will install the latest version of Abjad which works on your
#       version of Python.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
