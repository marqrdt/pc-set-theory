# %%
import abjad

# %%
score = abjad.Score(name="Score 1")
staff1 = abjad.Staff(name="Line 1")
tup = abjad.Tuplet((2, 3), "r8 c''4")
tup_string = r"\times 2/3 { r8 c''4\laissezVibrer}"
# staff1.extend(tup)
staff1.extend(tup_string)
staff1.extend("r4 r4 r4")
staff1.extend("r4 r4 r8 ds'8\laissezVibrer r4")
score.append( staff1 )
staff2 = abjad.Staff(name="Line 2")
staff2.extend("r4 r4 r4")
# tup2 = abjad.Tuplet((5, 4), "r8. as''8")
tup2_string = r"\times 4/5 { r8. as''8\laissezVibrer}"
staff2.extend(tup2_string)
score.append(staff2)
abjad.show(score)
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
tup = abjad.Tuplet((2, 3), "r8 c''4", hide=False)

# %%
staff1.extend(tup)

# %%
staff1.extend("r4 r4 r4")

# %%
staff1.extend("r4 r4 r8 ds'8 r4")

# %%
score = abjad.Score(name="Score 1")

# %%
score.append( staff1 )

# %%
abjad.show(score)
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
staff2 = abjad.Staff(name="Line 2")

# %%
tup = abjad.Tuplet("5:4", "r8. e''8")

# %%
staff2.extend("r4 r4 r4")

# %%
staff2.extend(tup)

# %%
staff2.extend("r4 r8 fs'8 r4 r4")

# %%
score.append(staff2)

# %%
abjad.show(tup)
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
my_score = abjad.Score("{ c,4 r4 r4 r4 r16 c'8. r4 r4 r4 } { r1 r16 cs,8. r4 r4 r4 r1 { 4/5 r4 cs''16 } r4 r4 r4 }", name='Mobiles Score', simultaneous=True)
# Out:
# ---------------------------------------------------------------------------
# LilyPondParserError                       Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 my_score = abjad.Score("{ c,4 r4 r4 r4 r16 c'8. r4 r4 r4 } { r1 r16 cs,8. r4 r4 r4 r1 { 4/5 r4 cs''16 } r4 r4 r4 }", name='Mobiles Score', simultaneous=True)
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:4482, in Score.__init__(self, components, lilypond_type, simultaneous, name, tag, language)
#    4472 def __init__(
#    4473     self,
#    4474     components=None,
#    (...)
#    4480     language: str = "english",
#    4481 ) -> None:
# -> 4482     Context.__init__(
#    4483         self,
#    4484         components=components,
#    4485         language=language,
#    4486         lilypond_type=lilypond_type,
#    4487         simultaneous=simultaneous,
#    4488         name=name,
#    4489         tag=tag,
#    4490     )
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:2966, in Context.__init__(self, components, lilypond_type, simultaneous, name, tag, language)
#    2964 self._remove_commands: list[str] = []
#    2965 self.lilypond_type = lilypond_type
# -> 2966 Container.__init__(
#    2967     self,
#    2968     simultaneous=simultaneous,
#    2969     components=components,
#    2970     language=language,
#    2971     name=name,
#    2972     tag=tag,
#    2973 )
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:829, in Container.__init__(self, components, identifier, simultaneous, name, tag, language)
#     827 # sets name temporarily for _find_correct_effective_context:
#     828 self._name = name
# --> 829 self._initialize_components(components, language=language)
#     830 self.identifier = identifier
#     831 self.simultaneous = bool(simultaneous)
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:1291, in Container._initialize_components(self, components, language)
#    1289             raise Exception(f"must be component: {component!r}.")
#    1290 if isinstance(components, str):
# -> 1291     parsed = self._parse_string(components, language=language)
#    1292     self._components = []
#    1293     self.simultaneous = parsed.simultaneous
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:1313, in Container._parse_string(self, string, language)
#    1311 if not user_input.startswith("<<") or not user_input.endswith(">>"):
#    1312     user_input = f"{{ {user_input} }}"
# -> 1313 parsed = self._parse_lilypond_string(user_input, language=language)
#    1314 assert isinstance(parsed, Container)
#    1315 return parsed
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/score.py:71, in Component._parse_lilypond_string(string, language)
#      67 @staticmethod
#      68 def _parse_lilypond_string(string, language="english"):
#      69     from .parsers.parse import parse
# ---> 71     return parse(string, language=language)
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/parsers/parse.py:35, in parse(string, language)
#      33     parser = LilyPondParser(default_language=language)
#      34     _lilypond_parsers_by_language[language] = parser
# ---> 35 return _lilypond_parsers_by_language[language](string)
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/parsers/parser.py:2760, in LilyPondParser.__call__(self, input_string)
#    2756     result = self._parser._lilypond_patch_parse_debug(
#    2757         input_string, lexer=self._lexer, debug=self._logger
#    2758     )
#    2759 else:
# -> 2760     result = self._parser._lilypond_patch_parse(input_string, lexer=self._lexer)
#    2761 return result
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/parsers/parser.py:1053, in _parse(self, input, lexer, debug, tracking, tokenfunc)
#    1051 if errtoken and not hasattr(errtoken, "lexer"):
#    1052     errtoken.lexer = lexer
# -> 1053 tok = self.errorfunc(errtoken)
#    1054 del errok, token, restart  # Delete special functions
#    1056 if self.errorok:
#    1057     # User must have done some kind of panic
#    1058     # mode recovery on their own.  The
#    1059     # returned token is the next self.lookahead
#
# File ~/virtualenvs/composition-python310/lib/python3.10/site-packages/abjad/parsers/parser.py:6621, in LilyPondSyntacticalDefinition.p_error(self, p)
#    6619 def p_error(self, p):
#    6620     # print p
# -> 6621     raise _exceptions.LilyPondParserError(p)
#
# LilyPondParserError: LexToken(FRACTION,<abjad.parsers.parser.LilyPondFraction object at 0x7fa5369e6530>,1,66)

# %%
from music21 import *

# %%
p1 = pitch.Pitch('b-4')

# %%
p1.pitchClass
# Out:
# 10

# %%
n1 = note.Note(pitch=75)

# %%
n1.pitch
# Out:
# <music21.pitch.Pitch D4>

# %%
n1.duration
# Out:
# <music21.duration.Duration 1.0>

# %%
n1.duration.quarterLength = 6.25

# %%
n1.show()

# %%
from fractions import Fraction
r1 = note.Rest(Fraction(2, 5))

# %%
r1.quarterLength = 0.4

# %%
r1.show()

# %%
t = duration.Tuplet(5, 4)

# %%
t.setDurationType('16th')

# %%
rd = duration.Duration(typeOrDuration=0.2)
rd.tuplets
rd.quarterLength = 1.0

# %%
rd.quarterLength
# Out:
# 1.0

# %%
r2 = note.Rest(rd, quarterLength=0.5)
r2.show()

# %%
n1 = note.Note('e-4', typeOrDuration=Fraction(3,5))

# %%
n1.quarterLength = 0.6

# %%
from fractions import Fraction
r1 = note.Rest(Fraction(2, 5))
r1.quarterLength = Fraction(2, 5)
n1 = note.Note('e-4', typeOrDuration=Fraction(3,5))
n1.quarterLength = Fraction(3, 5)
n2 = note.Note('e-4', typeOrDuration=Fraction(1,3))
n2.quarterLength = Fraction(1,3)
r2 = note.Rest(Fraction(2,3))
r2.quarterLength = Fraction(2, 3)
qr = note.Rest(typeOrDuration=1)
hr = note.Rest(type='half')

# %%
hr.show()

# %%
str1 = None
str1 = stream.Stream()
str1.append(r1)
str1.append(n1)
str1.append(qr)
str2 = None
str2 = stream.Stream()
str2.append(qr)
str2.append(r2)
str2.append(n2)

# %%
str1.show()

# %%
str1.duration
# Out:
# <music21.duration.Duration 2.0>

# %%
str2.show()

# %%
str2.duration
# Out:
# <music21.duration.Duration 2.0>

# %%
ps1 = stream.PartStaff()
ps2 = stream.PartStaff()
ps1.append(str1)
ps2.append(str2)
m1 = stream.Measure(number=1)
m1.timeSignature = meter.TimeSignature('4/4')
m1.append([ps1, ps2])
main_score = stream.Score()
main_score.insert(0, str1)
main_score.insert(0, str2)
main_score.show()

# %%
m1.duration
# Out:
# <music21.duration.Duration 4.0>

# %%
m1.makeNotation().show()

# %%
prt1 = stream.PartStaff([m1])

# %%
sc1 = stream.Score(prt1)

# %%
sc1.show()

# %%
sc1.duration
# Out:
# <music21.duration.Duration 2.0>

# %%
musicxml.m21ToXml(sc1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[327], line 1
# ----> 1 musicxml.m21ToXml(sc1)
#
# TypeError: 'module' object is not callable
