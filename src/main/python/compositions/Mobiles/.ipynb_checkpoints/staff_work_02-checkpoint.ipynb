# %%
from music21 import *
s = stream.Score(id='mainScore')
p0 = stream.Part(id='part0')
p1 = stream.Part(id='part1')

qr = note.Rest(typeOrDuration=1)
hr = note.Rest(type='half')
wr = note.Rest(type='whole')

from fractions import Fraction
r1 = note.Rest(Fraction(2, 5))
r1.quarterLength = Fraction(2, 5)
n1 = note.Note('e-4', typeOrDuration=Fraction(3,5))
n1.quarterLength = Fraction(3, 5)
n1.id = '234978'
n2 = note.Note(49, typeOrDuration=Fraction(1,3))
n2.quarterLength = Fraction(1,3)
r2 = note.Rest(Fraction(2,3))
r2.quarterLength = Fraction(2, 3)

m01 = stream.Measure(number=1)
m01.append(r1)
soft_dyn = dynamics.Dynamic('pp')
m01.append(soft_dyn)
m01.append(n1)
m01.append(qr)
m01.append(hr)
m02 = stream.Measure(number=2)
m02.append(qr)
m02.append(r2)
m02.append(n2)
m02.append(hr)
p0.append([m01, m02])

m11 = stream.Measure(number=1)
m11.append(qr)
m11.append(r2)
m11.append(n2)
m11.append(hr)
m12 = stream.Measure(number=2)
m12.append(hr)
m12.append(r1)
loud_dyn = dynamics.Dynamic('ff')
m12.append(loud_dyn)
m12.append(n1)
m12.append(qr)
p1.append([m11, m12])

s.insert(0, p0)
s.insert(0, p1)
s.show('text')
s.show()
# Out:
# {0.0} <music21.stream.Part part0>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.note.Rest 2/5ql>
#         {0.4} <music21.dynamics.Dynamic pp>
#         {0.4} <music21.note.Note E->
#         {1.0} <music21.note.Rest quarter>
#         {2.0} <music21.note.Rest half>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Rest quarter>
#         {1.0} <music21.note.Rest 2/3ql>
#         {1.6667} <music21.note.Note C#>
#         {2.0} <music21.note.Rest half>
# {0.0} <music21.stream.Part part1>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.note.Rest quarter>
#         {1.0} <music21.note.Rest 2/3ql>
#         {1.6667} <music21.note.Note C#>
#         {2.0} <music21.note.Rest half>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Rest half>
#         {2.0} <music21.note.Rest 2/5ql>
#         {2.4} <music21.dynamics.Dynamic ff>
#         {2.4} <music21.note.Note E->
#         {3.0} <music21.note.Rest quarter>

# %%
r32 = note.Rest(type='32nd')
r32.quarterLength = 0.125
r32.show()
r32.show('text')
# Out:
# <music21.note.Rest 32nd>

# %%
from music21 import *
dir(note.Note)
# Out:
# ['_DOC_ATTR',
#  '_DOC_ORDER',
#  '__annotations__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_classSetCacheDict',
#  '_classTupleCacheDict',
#  '_deepcopySubclassable',
#  '_getActiveSite',
#  '_getLyric',
#  '_getMeasureOffset',
#  '_getName',
#  '_getNameWithOctave',
#  '_getOctave',
#  '_getPriority',
#  '_getSeconds',
#  '_getStemDirection',
#  '_getStoredInstrument',
#  '_getTimeSignatureForBeat',
#  '_getVolume',
#  '_reprInternal',
#  '_reprText',
#  '_reprTextLine',
#  '_setActiveSite',
#  '_setLyric',
#  '_setName',
#  '_setNameWithOctave',
#  '_setOctave',
#  '_setPriority',
#  '_setSeconds',
#  '_setStemDirection',
#  '_setStoredInstrument',
#  '_setVolume',
#  '_styleClass',
#  'activeSite',
#  'addLyric',
#  'augmentOrDiminish',
#  'beat',
#  'beatDuration',
#  'beatStr',
#  'beatStrength',
#  'classSet',
#  'classSortOrder',
#  'classes',
#  'clearCache',
#  'containerHierarchy',
#  'contextSites',
#  'derivation',
#  'duration',
#  'editorial',
#  'fullName',
#  'getAllContextsByClass',
#  'getContextByClass',
#  'getGrace',
#  'getInstrument',
#  'getOffsetBySite',
#  'getOffsetInHierarchy',
#  'getSpannerSites',
#  'hasEditorialInformation',
#  'hasStyleInformation',
#  'hasVolumeInformation',
#  'id',
#  'informSites',
#  'insertLyric',
#  'isChord',
#  'isClassOrSubclass',
#  'isNote',
#  'isRest',
#  'isStream',
#  'lyric',
#  'measureNumber',
#  'mergeAttributes',
#  'name',
#  'nameWithOctave',
#  'next',
#  'notehead',
#  'noteheadFill',
#  'noteheadParenthesis',
#  'octave',
#  'offset',
#  'pitchChanged',
#  'pitches',
#  'previous',
#  'priority',
#  'purgeLocations',
#  'purgeOrphans',
#  'quarterLength',
#  'seconds',
#  'setOffsetBySite',
#  'show',
#  'sortTuple',
#  'splitAtDurations',
#  'splitAtQuarterLength',
#  'splitByQuarterLengths',
#  'stemDirection',
#  'step',
#  'storedInstrument',
#  'style',
#  'tie',
#  'transpose',
#  'volume',
#  'write']
